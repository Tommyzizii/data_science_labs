# %%
print("World Hello")
# Out:
# World Hello

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

books = pd.read_csv('clean_books.csv')
sns.histplot(data = books, x = 'rating')
plt.show()

# %%
books.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  rating  year        genre
# 0                  JJ Smith     4.7  2016  Non Fiction
# 1              Stephen King     4.6  2011      Fiction
# 2        Jordan B. Peterson     4.7  2018  Non Fiction
# 3             George Orwell     4.7  2017      Fiction
# 4  National Geographic Kids     4.8  2019    Childrens

# %%
unemployment = pd.read_csv('clean_unemployment.csv')
unemployment.head(20)
# Out:
#    country_code            country_name      continent   2010   2011   2012  \
# 0           AFG             Afghanistan           Asia  11.35  11.05  11.34
# 1           AGO                  Angola         Africa   9.43   7.36   7.35
# 2           ALB                 Albania         Europe  14.09  13.48  13.38
# 3           ARE    United Arab Emirates           Asia   2.48   2.30   2.18
# 4           ARG               Argentina  South America   7.71   7.18   7.22
# 5           ARM                 Armenia           Asia  19.01  18.44  17.30
# 6           AUS               Australia        Oceania   5.21   5.08   5.22
# 7           AUT                 Austria         Europe   4.82   4.56   4.87
# 8           AZE              Azerbaijan           Asia   5.63   5.42   5.19
# 9           BDI                 Burundi         Africa   1.61   1.60   1.59
# 10          BEL                 Belgium         Europe   8.29   7.14   7.54
# ...

# %%
sns.histplot(data=unemployment,x='2021',binwidth=0.1)
plt.show()

# %%
series_not_oceania = unemployment[~ unemployment['continent'].isin(['Oceania'])]
series_not_oceania.head()
# Out:
#   country_code          country_name      continent   2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1          AGO                Angola         Africa   9.43   7.36   7.35
# 2          ALB               Albania         Europe  14.09  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4          ARG             Argentina  South America   7.71   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
not_Oceania_2021 = series_not_oceania['2021']
print(not_Oceania_2021.min())
print(not_Oceania_2021.max())
# Out:
# 0.26
# 33.56

# %%
sns.boxplot(data=series_not_oceania,x='2021')
plt.show()

# %%
books.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  rating  year        genre
# 0                  JJ Smith     4.7  2016  Non Fiction
# 1              Stephen King     4.6  2011      Fiction
# 2        Jordan B. Peterson     4.7  2018  Non Fiction
# 3             George Orwell     4.7  2017      Fiction
# 4  National Geographic Kids     4.8  2019    Childrens

# %%
books.groupby('genre').mean(numeric_only=True)
# Out:
#                rating         year
# genre
# Childrens    4.780000  2015.075000
# Fiction      4.570229  2013.022901
# Non Fiction  4.598324  2013.513966

# %%
books[['rating','year']].agg(['mean','std'])
# Out:
#         rating         year
# mean  4.608571  2013.508571
# std   0.226941     3.284711

# %%
num = list(unemployment.select_dtypes(include=np.number).columns)
unemployment[num].agg(['mean','std'])
# Out:
#           2010      2011      2012      2013      2014      2015      2016  \
# mean  8.409286  8.315440  8.317967  8.344780  8.179670  8.058901  7.925879
# std   6.248887  6.266795  6.367270  6.416041  6.284241  6.161170  6.045439
#
#           2017      2018      2019      2020      2021
# mean  7.668626  7.426429  7.243736  8.420934  8.390879
# std   5.902152  5.818915  5.696573  6.040915  6.067192

# %%
num = list(unemployment.select_dtypes(include=np.number).columns)
unemployment.groupby('continent')[num].agg(['mean','std'])
# Out:
#                     2010                 2011                 2012            \
#                     mean       std       mean       std       mean       std
# continent
# Africa          9.343585  7.411259   9.369245  7.401556   9.240755  7.264542
# Asia            6.240638  5.146175   5.942128  4.779575   5.835319  4.756904
# Europe         11.008205  6.392063  10.947949  6.539538  11.325641  7.003527
# North America   8.663333  5.115805   8.563333  5.377041   8.448889  5.495819
# Oceania         3.622500  2.054721   3.647500  2.008466   4.103750  2.723118
# South America   6.870833  2.807058   6.518333  2.801577   6.410833  2.936508
#
#                     2013                 2014            ...      2017  \
#                     mean       std       mean       std  ...      mean
# continent                                                ...
# Africa          9.132453  7.309285   9.121321  7.291359  ...  9.284528
# ...

# %%
mean_rate = unemployment.groupby('continent')['2021'].mean().reset_index()
print(mean_rate)
# Out:
#        continent       2021
# 0         Africa  10.473585
# 1           Asia   6.906170
# 2         Europe   7.414872
# 3  North America   9.155000
# 4        Oceania   4.280000
# 5  South America   9.924167

# %%
std_rate = unemployment.groupby('continent')['2021'].agg(['std']).reset_index()
print(std_rate)
# Out:
#        continent       std
# 0         Africa  8.131636
# 1           Asia  5.414745
# 2         Europe  3.947825
# 3  North America  5.076482
# 4        Oceania  2.671522
# 5  South America  3.611624

# %%
continent_summary = unemployment.groupby("continent").agg(
    max_rate_2021 = ('2021','mean'),
    std_rate_2021 = ('2021','std')
)
continent_summary
# Out:
#                max_rate_2021  std_rate_2021
# continent
# Africa             10.473585       8.131636
# Asia                6.906170       5.414745
# Europe              7.414872       3.947825
# North America       9.155000       5.076482
# Oceania             4.280000       2.671522
# South America       9.924167       3.611624

# %%
sns.barplot(data=unemployment,x='continent',y='2021')
plt.show()

# %%
planes = pd.read_csv('Airlines_unclean.csv',index_col=0)
planes.isna().sum()
# Out:
# Airline            427
# Date_of_Journey    322
# Source             187
# Destination        347
# Route              256
# Dep_Time           260
# Arrival_Time       194
# Duration           214
# Total_Stops        212
# Additional_Info    589
# Price              616
# dtype: int64

# %%
thereshold = len(planes)*0.05
print(thereshold)
# Out:
# 533.0

# %%
planes.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
cols_to_drop = planes.columns[planes.isna().sum() <= thereshold]
print(cols_to_drop)
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops'],
#       dtype='object')

# %%
planes.dropna(subset = cols_to_drop,inplace=True)

# %%
planes.isna().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info    300
# Price              368
# dtype: int64

# %%
cols_with_missing_vales = planes.columns[planes.isna().sum() > 0]
print(cols_with_missing_vales)
# Out:
# Index(['Additional_Info', 'Price'], dtype='object')

# %%
for col in cols_with_missing_vales[:-1]:
    planes[col].fillna(planes[col].mode()[0])

# %%
planes.isna().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info    300
# Price              368
# dtype: int64

# %%
planes['Additional_Info'].value_counts()
# Out:
# Additional_Info
# No info                         6399
# In-flight meal not included     1525
# No check-in baggage included     258
# 1 Long layover                    14
# Change airports                    7
# No Info                            2
# Business class                     1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
planes.dropna(subset='Additional_Info',inplace=True)
planes.isna().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info      0
# Price              360
# dtype: int64

# %%
price_dict = planes.groupby('Airline')['Price'].mean().to_dict()

# %%
planes['Price'] = planes['Price'].fillna(planes['Airline'].map(price_dict))
planes.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
planes.select_dtypes(object)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways        9/6/2019     Delhi      Cochin
# 1           IndiGo       12/5/2019   Kolkata    Banglore
# 2           IndiGo        1/3/2019  Banglore   New Delhi
# 3         SpiceJet       24/6/2019   Kolkata    Banglore
# 4      Jet Airways       12/3/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10654     SpiceJet       21/5/2019  Banglore       Delhi
# 10655     Air Asia        9/4/2019   Kolkata    Banglore
# 10656    Air India       27/4/2019   Kolkata    Banglore
# 10658      Vistara        1/3/2019  Banglore   New Delhi
# 10659    Air India        9/5/2019     Delhi      Cochin
#
#                        Route Dep_Time     Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK     9:25   10/6/2023 4:25      19h     2 stops
# 1            CCU → NAG → BLR    18:05            23:30   5h 25m      1 stop
# ...

# %%
planes['Airline'].value_counts()
# Out:
# Airline
# Jet Airways          2964
# IndiGo               1585
# Air India            1346
# Multiple carriers     931
# SpiceJet              632
# Vistara               362
# Air Asia              248
# GoAir                 140
# Name: count, dtype: int64

# %%
planes['Airline'].nunique()
# Out:
# 8

# %%
salaries.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 salaries.head()
#
# NameError: name 'salaries' is not defined

# %%
salaries.select_dtypes(object)
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     salary_currency employee_residence company_location company_size
# 0               EUR                 DE               DE            L
# ...

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# ...

# %%
non_numeric = planes.select_dtypes("object")
print(non_numeric)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways        9/6/2019     Delhi      Cochin
# 1           IndiGo       12/5/2019   Kolkata    Banglore
# 2           IndiGo        1/3/2019  Banglore   New Delhi
# 3         SpiceJet       24/6/2019   Kolkata    Banglore
# 4      Jet Airways       12/3/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10654     SpiceJet       21/5/2019  Banglore       Delhi
# 10655     Air Asia        9/4/2019   Kolkata    Banglore
# 10656    Air India       27/4/2019   Kolkata    Banglore
# 10658      Vistara        1/3/2019  Banglore   New Delhi
# 10659    Air India        9/5/2019     Delhi      Cochin
#
#                        Route Dep_Time     Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK     9:25   10/6/2023 4:25      19h     2 stops
# 1            CCU → NAG → BLR    18:05            23:30   5h 25m      1 stop
# ...

# %%
for cols in non_numeric.columns:
    print(f"Number of unique values in {cols} column: ", non_numeric[cols].nunique())
# Out:
# Number of unique values in Airline column:  8
# Number of unique values in Date_of_Journey column:  40
# Number of unique values in Source column:  5
# Number of unique values in Destination column:  6
# Number of unique values in Route column:  122
# Number of unique values in Dep_Time column:  218
# Number of unique values in Arrival_Time column:  1200
# Number of unique values in Duration column:  362
# Number of unique values in Total_Stops column:  5
# Number of unique values in Additional_Info column:  9

# %%
# Filter the DataFrame for object columns
non_numeric = planes.select_dtypes("object")
 
# Loop through columns
for col in non_numeric.columns:
  
  # Print the number of unique values
  print(f"Number of unique values in {col} column: ", non_numeric[col].nunique())
# Out:
# Number of unique values in Airline column:  8
# Number of unique values in Date_of_Journey column:  40
# Number of unique values in Source column:  5
# Number of unique values in Destination column:  6
# Number of unique values in Route column:  122
# Number of unique values in Dep_Time column:  218
# Number of unique values in Arrival_Time column:  1200
# Number of unique values in Duration column:  362
# Number of unique values in Total_Stops column:  5
# Number of unique values in Additional_Info column:  9

# %%
planes['Duration'].head()
# Out:
# 0        19h
# 1     5h 25m
# 2     4h 45m
# 3     2h 25m
# 4    15h 30m
# Name: Duration, dtype: object

# %%
flight_category = ['short flight','mid flight', 'long flight']

# %%
short_flight = "0h|1h|2h|3h|4h"
mid_flight = "5h|6h|7h|8h|9h"
long_flight = "10h|11h|12h|13h|14h|15h|16h"

# %%
conditions = [(planes['Duration'].str.contains(short_flight)),
              (planes['Duration'].str.contains(mid_flight)),
              (planes['Duration'].str.contains(long_flight))]

# %%
planes['Duration_Category'] = np.select(
    conditions,
    flight_category,
    default="Other"
)

# %%
planes[['Duration','Duration_Category']].head()
# Out:
#   Duration Duration_Category
# 0      19h        mid flight
# 1   5h 25m        mid flight
# 2   4h 45m      short flight
# 3   2h 25m      short flight
# 4  15h 30m        mid flight

# %%
sns.countplot(data=planes,x='Duration_Category')
plt.show()

# %%
salaries.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
salarie_with_rupees = pd.read_csv('Salary_Rupee_USD.csv')
salarie_with_rupees.head()
# Out:
#    Unnamed: 0  Working_Year                 Designation Experience  \
# 0           0          2020  Machine Learning Scientist         SE
# 1           1          2020           Big Data Engineer         SE
# 2           2          2020        Product Data Analyst         MI
# 3           3          2020   Machine Learning Engineer         SE
# 4           4          2020                Data Analyst         EN
#
#   Employment_Status  Salary_In_Rupees Employee_Location Company_Location  \
# 0                FT        20700000.0                JP               JP
# 1                FT         8680000.0                GB               GB
# 2                FT         1590000.0                HN               HN
# 3                FT        11900000.0                US               US
# 4                FT         5730000.0                US               US
#
#   Company_Size  Remote_Working_Ratio  Salary_USD      Job_Category
# ...

# %%
salarie_with_rupees.select_dtypes("number")
# Out:
#      Unnamed: 0  Working_Year  Salary_In_Rupees  Remote_Working_Ratio  \
# 0             0          2020        20700000.0                     0
# 1             1          2020         8680000.0                    50
# 2             2          2020         1590000.0                     0
# 3             3          2020        11900000.0                    50
# 4             4          2020         5730000.0                   100
# ..          ...           ...               ...                   ...
# 402         402          2022        12300000.0                   100
# 403         403          2022        10000000.0                   100
# 404         404          2022        10300000.0                     0
# 405         405          2022        11900000.0                   100
# 406         406          2022        15900000.0                   100
#
#      Salary_USD
# 0    248256.840
# 1    104099.820
# 2     19096.680
# 3    143225.100
# 4     68748.048
# ..          ...
# ...

# %%
salarie_with_rupees['Salary_In_USD'] = salarie_with_rupees['Salary_In_Rupees'] * 0.012

# %%
salarie_with_rupees[["Salary_In_Rupees","Salary_In_USD"]].head()
# Out:
#    Salary_In_Rupees  Salary_In_USD
# 0        20700000.0       248400.0
# 1         8680000.0       104160.0
# 2         1590000.0        19080.0
# 3        11900000.0       142800.0
# 4         5730000.0        68760.0

# %%
salarie_with_rupees.groupby("Working_Year")['Salary_In_USD'].mean()
# Out:
# Working_Year
# 2020     99289.565217
# 2021     91119.380282
# 2022    117979.506849
# Name: Salary_In_USD, dtype: float64

# %%
salarie_with_rupees["std_dev"] = salarie_with_rupees.groupby("Working_Year")['Salary_In_USD'].transform(lambda x: x.std())

# %%
salarie_with_rupees[["std_dev","Salary_In_USD"]].head()
# Out:
#         std_dev  Salary_In_USD
# 0  71375.229658       248400.0
# 1  71375.229658       104160.0
# 2  71375.229658        19080.0
# 3  71375.229658       142800.0
# 4  71375.229658        68760.0

# %%
planes['Duration'].head()
# Out:
# 0        19h
# 1     5h 25m
# 2     4h 45m
# 3     2h 25m
# 4    15h 30m
# Name: Duration, dtype: object

# %%
planes['Duration'] = planes['Duration'].str.replace("h",".")
planes['Duration'] = planes['Duration'].str.replace("m","")
planes['Duration'] = planes['Duration'].str.replace(" ","")

# %%
planes['Duration'].head()
# Out:
# 0      19.
# 1     5.25
# 2     4.45
# 3     2.25
# 4    15.30
# Name: Duration, dtype: object

# %%
planes['Duration'] = planes['Duration'].astype(float)

# %%
sns.histplot(data=planes,x='Duration')
# Out:
# <Axes: xlabel='Duration', ylabel='Count'>

# %%
planes['std_dev'] = planes.groupby('Airline')['Price'].transform(lambda x: x.std())

# %%
planes['airline_median_duration'] = planes.groupby('Airline')['Duration'].transform(lambda x: x.median())

# %%
planes.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0  Jet Airways        9/6/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 1       IndiGo       12/5/2019   Kolkata    Banglore        CCU → NAG → BLR
# 2       IndiGo        1/3/2019  Banglore   New Delhi        BLR → NAG → DEL
# 3     SpiceJet       24/6/2019   Kolkata    Banglore              CCU → BLR
# 4  Jet Airways       12/3/2019  Banglore   New Delhi        BLR → BOM → DEL
#
#   Dep_Time     Arrival_Time  Duration Total_Stops  \
# 0     9:25   10/6/2023 4:25     19.00     2 stops
# 1    18:05            23:30      5.25      1 stop
# 2    16:50            21:35      4.45      1 stop
# 3     9:00            11:25      2.25    non-stop
# 4    18:55  13/3/2023 10:25     15.30      1 stop
#
#                Additional_Info    Price      std_dev  airline_median_duration
# 0                      No info  13882.0  4188.976319                    13.20
# ...

# %%
planes['Price-Destination'] = planes.groupby('Destination')['Price'].transform(lambda x: x.mean()) # for each group

# %%
planes[['Price-Destination','Destination']].head()
# Out:
#    Price-Destination Destination
# 0       10465.095719      Cochin
# 1        9114.492445    Banglore
# 2       11595.194040   New Delhi
# 3        9114.492445    Banglore
# 4       11595.194040   New Delhi

# %%
std = planes.groupby('Destination')['Price'].agg('std') # for one row
print(std)
# Out:
# Destination
# Banglore     3759.002686
# Cochin       3595.695996
# Delhi        1498.822673
# Hyderabad    4080.236148
# Kolkata      2261.132212
# New Delhi    6449.873420
# Name: Price, dtype: float64

# %%
price_seventy_fifth = planes['Price'].quantile(0.75)
price_twenty_fifth = planes['Price'].quantile(0.25)
in_qr = price_seventy_fifth - price_twenty_fifth
print(in_qr)
# Out:
# 6839.0

# %%
upper = price_seventy_fifth + (1.5 * in_qr)
lower = price_twenty_fifth - (1.5 * in_qr)

# %%
no_outliners = planes[(planes['Price'] > lower) & (planes['Price'] < upper)]
no_outliners.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0  Jet Airways        9/6/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 1       IndiGo       12/5/2019   Kolkata    Banglore        CCU → NAG → BLR
# 2       IndiGo        1/3/2019  Banglore   New Delhi        BLR → NAG → DEL
# 3     SpiceJet       24/6/2019   Kolkata    Banglore              CCU → BLR
# 4  Jet Airways       12/3/2019  Banglore   New Delhi        BLR → BOM → DEL
#
#   Dep_Time     Arrival_Time  Duration Total_Stops  \
# 0     9:25   10/6/2023 4:25     19.00     2 stops
# 1    18:05            23:30      5.25      1 stop
# 2    16:50            21:35      4.45      1 stop
# 3     9:00            11:25      2.25    non-stop
# 4    18:55  13/3/2023 10:25     15.30      1 stop
#
#                Additional_Info    Price      std_dev  airline_median_duration  \
# 0                      No info  13882.0  4188.976319                    13.20
# ...
