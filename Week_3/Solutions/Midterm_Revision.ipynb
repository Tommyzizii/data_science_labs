# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# FILERTING,
# SORTING,
# SUBSETTING (WITH CONDITIONS)

# %%
import pandas as pd
taxi_owner = pd.read_pickle("taxi_owners.p")
taxi_owner.head()
# Out:
#      rid   vid           owner                 address    zip
# 0  T6285  6285  AGEAN TAXI LLC     4536 N. ELSTON AVE.  60630
# 1  T4862  4862    MANGIB CORP.  5717 N. WASHTENAW AVE.  60659
# 2  T1495  1495   FUNRIDE, INC.     3351 W. ADDISON ST.  60618
# 3  T4231  4231    ALQUSH CORP.   6611 N. CAMPBELL AVE.  60645
# 4  T5971  5971  EUNIFFORD INC.     3351 W. ADDISON ST.  60618

# %%
homelessness = pd.read_csv('homelessness.csv')
homelessness.head(10)
# Out:
#    Unnamed: 0              region                 state  individuals  \
# 0           0  East South Central               Alabama       2570.0
# 1           1             Pacific                Alaska       1434.0
# 2           2            Mountain               Arizona       7259.0
# 3           3  West South Central              Arkansas       2280.0
# 4           4             Pacific            California     109008.0
# 5           5            Mountain              Colorado       7607.0
# 6           6         New England           Connecticut       2280.0
# 7           7      South Atlantic              Delaware        708.0
# 8           8      South Atlantic  District of Columbia       3770.0
# 9           9      South Atlantic               Florida      21443.0
#
#    family_members  state_pop
# 0           864.0    4887681
# 1           582.0     735139
# 2          2606.0    7158024
# 3           432.0    3009733
# 4         20964.0   39461588
# ...

# %%
homelessness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   region          51 non-null     object
#  2   state           51 non-null     object
#  3   individuals     51 non-null     float64
#  4   family_members  51 non-null     float64
#  5   state_pop       51 non-null     int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
homelessness.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
homelessness.sort_values('individuals',ascending=False)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 4            4             Pacific            California     109008.0
# 32          32        Mid-Atlantic              New York      39827.0
# 9            9      South Atlantic               Florida      21443.0
# 43          43  West South Central                 Texas      19199.0
# 47          47             Pacific            Washington      16424.0
# 37          37             Pacific                Oregon      11139.0
# 38          38        Mid-Atlantic          Pennsylvania       8163.0
# 5            5            Mountain              Colorado       7607.0
# 2            2            Mountain               Arizona       7259.0
# 28          28            Mountain                Nevada       7058.0
# 10          10      South Atlantic               Georgia       6943.0
# 35          35  East North Central                  Ohio       6929.0
# ...

# %%
homelessness.sort_values(['individuals','family_members'],ascending=[True,True])
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 34          34  West North Central          North Dakota        467.0
# 7            7      South Atlantic              Delaware        708.0
# 39          39         New England          Rhode Island        747.0
# 45          45         New England               Vermont        780.0
# 29          29         New England         New Hampshire        835.0
# 41          41  West North Central          South Dakota        836.0
# 26          26            Mountain               Montana        983.0
# 48          48      South Atlantic         West Virginia       1021.0
# 24          24  East South Central           Mississippi       1024.0
# 12          12            Mountain                 Idaho       1297.0
# 1            1             Pacific                Alaska       1434.0
# ...

# %%
columns_subsets = ['individuals','family_members','state_pop']
homelessness[columns_subsets]
# Out:
#     individuals  family_members  state_pop
# 0        2570.0           864.0    4887681
# 1        1434.0           582.0     735139
# 2        7259.0          2606.0    7158024
# 3        2280.0           432.0    3009733
# 4      109008.0         20964.0   39461588
# 5        7607.0          3250.0    5691287
# 6        2280.0          1696.0    3571520
# 7         708.0           374.0     965479
# 8        3770.0          3134.0     701547
# 9       21443.0          9587.0   21244317
# 10       6943.0          2556.0   10511131
# 11       4131.0          2399.0    1420593
# 12       1297.0           715.0    1750536
# 13       6752.0          3891.0   12723071
# 14       3776.0          1482.0    6695497
# 15       1711.0          1038.0    3148618
# 16       1443.0           773.0    2911359
# 17       2735.0           953.0    4461153
# 18       2540.0           519.0    4659690
# 19       1450.0          1066.0    1339057
# 20       4914.0          2230.0    6035802
# ...

# %%
is_pacific = homelessness['region'] == "Pacific"
is_washington = homelessness['state'] == "Washington"
homelessness[is_pacific & is_washington]
# Out:
#     Unnamed: 0   region       state  individuals  family_members  state_pop
# 47          47  Pacific  Washington      16424.0          5880.0    7523869

# %%
pacific_mountain = homelessness['region'].isin(['Pacific','Mountain'])
homelessness[pacific_mountain]
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 1            1   Pacific      Alaska       1434.0           582.0     735139
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 4            4   Pacific  California     109008.0         20964.0   39461588
# 5            5  Mountain    Colorado       7607.0          3250.0    5691287
# 11          11   Pacific      Hawaii       4131.0          2399.0    1420593
# 12          12  Mountain       Idaho       1297.0           715.0    1750536
# 26          26  Mountain     Montana        983.0           422.0    1060665
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 31          31  Mountain  New Mexico       1949.0           602.0    2092741
# 37          37   Pacific      Oregon      11139.0          3337.0    4181886
# 44          44  Mountain        Utah       1904.0           972.0    3153550
# ...

# %%
homelessness_ind = homelessness.sort_values('individuals',ascending=True)
print(homelessness_ind)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 34          34  West North Central          North Dakota        467.0
# 7            7      South Atlantic              Delaware        708.0
# 39          39         New England          Rhode Island        747.0
# 45          45         New England               Vermont        780.0
# 29          29         New England         New Hampshire        835.0
# 41          41  West North Central          South Dakota        836.0
# 26          26            Mountain               Montana        983.0
# 48          48      South Atlantic         West Virginia       1021.0
# 24          24  East South Central           Mississippi       1024.0
# 12          12            Mountain                 Idaho       1297.0
# 1            1             Pacific                Alaska       1434.0
# ...

# %%
homelessness_fam = homelessness.sort_values('family_members',ascending=False)
homelessness_fam.head(10)
# Out:
#     Unnamed: 0              region          state  individuals  \
# 32          32        Mid-Atlantic       New York      39827.0
# 4            4             Pacific     California     109008.0
# 21          21         New England  Massachusetts       6811.0
# 9            9      South Atlantic        Florida      21443.0
# 43          43  West South Central          Texas      19199.0
# 47          47             Pacific     Washington      16424.0
# 38          38        Mid-Atlantic   Pennsylvania       8163.0
# 13          13  East North Central       Illinois       6752.0
# 30          30        Mid-Atlantic     New Jersey       6048.0
# 37          37             Pacific         Oregon      11139.0
#
#     family_members  state_pop
# 32         52070.0   19530351
# 4          20964.0   39461588
# 21         13257.0    6882635
# 9           9587.0   21244317
# 43          6111.0   28628666
# 47          5880.0    7523869
# 38          5349.0   12800922
# ...

# %%
homelessness_reg_fam = homelessness.sort_values(['region','family_members'],ascending=[True,False])
homelessness_reg_fam.head()
# Out:
#     Unnamed: 0              region      state  individuals  family_members  \
# 13          13  East North Central   Illinois       6752.0          3891.0
# 35          35  East North Central       Ohio       6929.0          3320.0
# 22          22  East North Central   Michigan       5209.0          3142.0
# 49          49  East North Central  Wisconsin       2740.0          2167.0
# 14          14  East North Central    Indiana       3776.0          1482.0
#
#     state_pop
# 13   12723071
# 35   11676341
# 22    9984072
# 49    5807406
# 14    6695497

# %%
state_fam = ['state','family_members']
homelessness[state_fam]
# Out:
#                    state  family_members
# 0                Alabama           864.0
# 1                 Alaska           582.0
# 2                Arizona          2606.0
# 3               Arkansas           432.0
# 4             California         20964.0
# 5               Colorado          3250.0
# 6            Connecticut          1696.0
# 7               Delaware           374.0
# 8   District of Columbia          3134.0
# 9                Florida          9587.0
# 10               Georgia          2556.0
# 11                Hawaii          2399.0
# 12                 Idaho           715.0
# 13              Illinois          3891.0
# 14               Indiana          1482.0
# 15                  Iowa          1038.0
# 16                Kansas           773.0
# 17              Kentucky           953.0
# 18             Louisiana           519.0
# 19                 Maine          1066.0
# 20              Maryland          2230.0
# 21         Massachusetts         13257.0
# ...

# %%
ind_gt_10k = homelessness['individuals'] > 10000
homelessness[ind_gt_10k]
# Out:
#     Unnamed: 0              region       state  individuals  family_members  \
# 4            4             Pacific  California     109008.0         20964.0
# 9            9      South Atlantic     Florida      21443.0          9587.0
# 32          32        Mid-Atlantic    New York      39827.0         52070.0
# 37          37             Pacific      Oregon      11139.0          3337.0
# 43          43  West South Central       Texas      19199.0          6111.0
# 47          47             Pacific  Washington      16424.0          5880.0
#
#     state_pop
# 4    39461588
# 9    21244317
# 32   19530351
# 37    4181886
# 43   28628666
# 47    7523869

# %%
mountain_reg = homelessness['region'] == 'Mountain'
homelessness[mountain_reg]
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 5            5  Mountain    Colorado       7607.0          3250.0    5691287
# 12          12  Mountain       Idaho       1297.0           715.0    1750536
# 26          26  Mountain     Montana        983.0           422.0    1060665
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 31          31  Mountain  New Mexico       1949.0           602.0    2092741
# 44          44  Mountain        Utah       1904.0           972.0    3153550
# 50          50  Mountain     Wyoming        434.0           205.0     577601

# %%
num_fam = homelessness['family_members'] < 1000
reg = homelessness['region'] == "Pacific"
fam_It_1k_pac = num_fam & reg
homelessness[fam_It_1k_pac]
# Out:
#    Unnamed: 0   region   state  individuals  family_members  state_pop
# 1           1  Pacific  Alaska       1434.0           582.0     735139

# %%
south = homelessness['region'] == "South Atlantic"
mid = homelessness['region'] == "Mid-Atlantic"
south_mid_atlantic = south | mid
homelessness[south_mid_atlantic]
# Out:
#     Unnamed: 0          region                 state  individuals  \
# 7            7  South Atlantic              Delaware        708.0
# 8            8  South Atlantic  District of Columbia       3770.0
# 9            9  South Atlantic               Florida      21443.0
# 10          10  South Atlantic               Georgia       6943.0
# 20          20  South Atlantic              Maryland       4914.0
# 30          30    Mid-Atlantic            New Jersey       6048.0
# 32          32    Mid-Atlantic              New York      39827.0
# 33          33  South Atlantic        North Carolina       6451.0
# 38          38    Mid-Atlantic          Pennsylvania       8163.0
# 40          40  South Atlantic        South Carolina       3082.0
# 46          46  South Atlantic              Virginia       3928.0
# 48          48  South Atlantic         West Virginia       1021.0
#
#     family_members  state_pop
# 7            374.0     965479
# 8           3134.0     701547
# ...

# %%
c = homelessness['state'] == 'California'
a = homelessness['state'] == 'Arizona'
n = homelessness['state'] == 'Nevada'
u = homelessness['state'] == 'Utah'
mojave_homelessness = c | a | n | u
homelessness[mojave_homelessness]
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 4            4   Pacific  California     109008.0         20964.0   39461588
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 44          44  Mountain        Utah       1904.0           972.0    3153550

# %%
mojave = homelessness['state'].isin(['California','Arizona','Nevada','Utah'])
homelessness[mojave]
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 4            4   Pacific  California     109008.0         20964.0   39461588
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 44          44  Mountain        Utah       1904.0           972.0    3153550

# %% [markdown]
# New Column

# %%
homelessness['total'] = homelessness['individuals'] + homelessness['family_members']
homelessness.head(51)
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
homelessness['p_individuals'] = homelessness['individuals'] / homelessness['total']
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop     total  p_individuals
# 0    4887681    3434.0       0.748398
# 1     735139    2016.0       0.711310
# 2    7158024    9865.0       0.735834
# 3    3009733    2712.0       0.840708
# 4   39461588  129972.0       0.838704

# %%
homelessness['indv_per_10k'] = 10000 * homelessness['individuals'] / homelessness['state_pop']
high_homelessness = homelessness[homelessness['indv_per_10k'] > 20]
high_homelessness_sort = high_homelessness.sort_values('indv_per_10k',ascending=False)
high_homelessness_sort[['individuals','indv_per_10k']].head()
# Out:
#     individuals  indv_per_10k
# 8        3770.0     53.738381
# 11       4131.0     29.079406
# 4      109008.0     27.623825
# 37      11139.0     26.636307
# 28       7058.0     23.314189

# %%
sales = pd.read_csv('sales_subset.csv')
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10774 non-null  int64
#  1   store                 10774 non-null  int64
#  2   type                  10774 non-null  object
#  3   department            10774 non-null  int64
#  4   date                  10774 non-null  object
#  5   weekly_sales          10774 non-null  float64
#  6   is_holiday            10774 non-null  bool
#  7   temperature_c         10774 non-null  float64
#  8   fuel_price_usd_per_l  10774 non-null  float64
#  9   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(3), object(2)
# memory usage: 768.2+ KB

# %%
print(sales['weekly_sales'].mean())
print(sales['weekly_sales'].median())
# Out:
# 23843.95014850566
# 12049.064999999999

# %%
print(sales['date'].min())
print(sales['date'].max())
# Out:
# 2010-02-05
# 2012-10-26

# %%
sales_1_1 = sales[(sales['department'] == 1) & (sales['store'] == 1)]
sales_1_1.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales_1_1 = sales_1_1.sort_values('date', ascending=True)
sales_1_1.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales_1_1['cum_weekly_sales'] = sales_1_1['weekly_sales'].cumsum()
sales_1_1.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment  cum_weekly_sales
# 0       5.727778              0.679451         8.106          24924.50
# 1       8.055556              0.693452         8.106          46752.40
# 2      16.816667              0.718284         7.808         104010.83
# 3      22.527778              0.748928         7.808         121424.77
# 4      27.050000              0.714586         7.808         138982.86

# %%
sales_1_1['cum_max_sales'] = sales_1_1['weekly_sales'].cummax()
sales_1_1.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment  cum_weekly_sales  \
# 0       5.727778              0.679451         8.106          24924.50
# 1       8.055556              0.693452         8.106          46752.40
# 2      16.816667              0.718284         7.808         104010.83
# 3      22.527778              0.748928         7.808         121424.77
# 4      27.050000              0.714586         7.808         138982.86
#
#    cum_max_sales
# 0       24924.50
# 1       24924.50
# 2       57258.43
# ...

# %%
sales_1_1[['date','weekly_sales','cum_weekly_sales','cum_max_sales']]
# Out:
#           date  weekly_sales  cum_weekly_sales  cum_max_sales
# 0   2010-02-05      24924.50          24924.50       24924.50
# 1   2010-03-05      21827.90          46752.40       24924.50
# 2   2010-04-02      57258.43         104010.83       57258.43
# 3   2010-05-07      17413.94         121424.77       57258.43
# 4   2010-06-04      17558.09         138982.86       57258.43
# 5   2010-07-02      16333.14         155316.00       57258.43
# 6   2010-08-06      17508.41         172824.41       57258.43
# 7   2010-09-03      16241.78         189066.19       57258.43
# 8   2010-10-01      20094.19         209160.38       57258.43
# 9   2010-11-05      34238.88         243399.26       57258.43
# 10  2010-12-03      22517.56         265916.82       57258.43
# 11  2011-01-07      15984.24         281901.06       57258.43

# %%
stores_types = sales.drop_duplicates(subset=['store','type'])
stores_types.head()
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 0              0      1    A           1  2010-02-05      24924.50
# 901          901      2    A           1  2010-02-05      35034.06
# 1798        1798      4    A           1  2010-02-05      38724.42
# 2699        2699      6    A           1  2010-02-05      25619.00
# 3593        3593     10    B           1  2010-02-05      40212.84
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0          False       5.727778              0.679451         8.106
# 901        False       4.550000              0.679451         8.324
# 1798       False       6.533333              0.686319         8.623
# 2699       False       4.683333              0.679451         7.259
# 3593       False      12.411111              0.782478         9.765

# %%
store_depts = sales.drop_duplicates(subset=['store','department'])
store_depts.head()
# Out:
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# 12          12      1    A           2  2010-02-05      50605.27       False
# 24          24      1    A           3  2010-02-05      13740.12       False
# 36          36      1    A           4  2010-02-05      39954.04       False
# 48          48      1    A           5  2010-02-05      32229.38       False
#
#     temperature_c  fuel_price_usd_per_l  unemployment
# 0        5.727778              0.679451         8.106
# 12       5.727778              0.679451         8.106
# 24       5.727778              0.679451         8.106
# 36       5.727778              0.679451         8.106
# 48       5.727778              0.679451         8.106

# %%
holiday = sales[sales['is_holiday'] == True]
holiday_dates = holiday.drop_duplicates(subset='date')
holiday_dates['date']
# Out:
# 498     2010-09-10
# 691     2011-11-25
# 2315    2010-02-12
# 6735    2012-09-07
# 6810    2010-12-31
# 6815    2012-02-10
# 6820    2011-09-09
# Name: date, dtype: object

# %%
stores_types['type'].value_counts()
stores_types['type'].value_counts(normalize=True)
# Out:
# type
# A    0.916667
# B    0.083333
# Name: proportion, dtype: float64

# %%
store_depts['department'].value_counts(ascending=False)
# Out:
# department
# 1     12
# 55    12
# 72    12
# 71    12
# 67    12
#       ..
# 37    10
# 48     8
# 50     6
# 39     4
# 43     2
# Name: count, Length: 80, dtype: int64

# %%
store_depts['department'].value_counts(normalize=True,ascending=False)
# Out:
# department
# 1     0.012917
# 55    0.012917
# 72    0.012917
# 71    0.012917
# 67    0.012917
#         ...
# 37    0.010764
# 48    0.008611
# 50    0.006459
# 39    0.004306
# 43    0.002153
# Name: proportion, Length: 80, dtype: float64

# %%
print(sales['weekly_sales'].sum())
# Out:
# 256894718.89999998

# %%
sales_A = sales[sales['type'] == 'A']['weekly_sales'].sum()
print(sales_A)
# Out:
# 233716315.01

# %%
sales_B = sales[sales['type'] == 'B']['weekly_sales'].sum()
print(sales_B)
# Out:
# 23178403.89

# %%
import numpy as np
sales_stats = sales.groupby('type')['weekly_sales'].agg([np.mean,np.median,max,min,sum])
sales_stats.head()
# Out:
# /var/folders/m3/z1dcknvs5nqcqxz3wl0jyjnm0000gn/T/ipykernel_44259/4149559204.py:2: FutureWarning: The provided callable <function mean at 0x1065a04a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   sales_stats = sales.groupby('type')['weekly_sales'].agg([np.mean,np.median,max,min,sum])
# /var/folders/m3/z1dcknvs5nqcqxz3wl0jyjnm0000gn/T/ipykernel_44259/4149559204.py:2: FutureWarning: The provided callable <function median at 0x1066e7880> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   sales_stats = sales.groupby('type')['weekly_sales'].agg([np.mean,np.median,max,min,sum])
# ...

# %%
unemp_fuel = sales.groupby('type')[['unemployment','fuel_price_usd_per_l']].agg([min,max,np.mean,np.median])
unemp_fuel.head()
# Out:
# /var/folders/m3/z1dcknvs5nqcqxz3wl0jyjnm0000gn/T/ipykernel_44259/673726921.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   unemp_fuel = sales.groupby('type')[['unemployment','fuel_price_usd_per_l']].agg([min,max,np.mean,np.median])
# /var/folders/m3/z1dcknvs5nqcqxz3wl0jyjnm0000gn/T/ipykernel_44259/673726921.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   unemp_fuel = sales.groupby('type')[['unemployment','fuel_price_usd_per_l']].agg([min,max,np.mean,np.median])
# ...

# %%
temperature = pd.read_csv('temperatures.csv')
tem_ind = temperature.set_index('city')
tem_ind.reset_index(drop = True)
# Out:
#        Unnamed: 0        date        country  avg_temp_c
# 0               0  2000-01-01  Côte D'Ivoire      27.293
# 1               1  2000-02-01  Côte D'Ivoire      27.685
# 2               2  2000-03-01  Côte D'Ivoire      29.061
# 3               3  2000-04-01  Côte D'Ivoire      28.162
# 4               4  2000-05-01  Côte D'Ivoire      27.547
# ...           ...         ...            ...         ...
# 16495       16495  2013-05-01          China      18.979
# 16496       16496  2013-06-01          China      23.522
# 16497       16497  2013-07-01          China      25.251
# 16498       16498  2013-08-01          China      24.528
# 16499       16499  2013-09-01          China         NaN
#
# [16500 rows x 4 columns]

# %%
cities = ["Moscow","Saint Petersburg"]
temperature[temperature['city'].isin(cities)]
# Out:
#        Unnamed: 0        date              city country  avg_temp_c
# 10725       10725  2000-01-01            Moscow  Russia      -7.313
# 10726       10726  2000-02-01            Moscow  Russia      -3.551
# 10727       10727  2000-03-01            Moscow  Russia      -1.661
# 10728       10728  2000-04-01            Moscow  Russia      10.096
# 10729       10729  2000-05-01            Moscow  Russia      10.357
# ...           ...         ...               ...     ...         ...
# 13360       13360  2013-05-01  Saint Petersburg  Russia      12.355
# 13361       13361  2013-06-01  Saint Petersburg  Russia      17.185
# 13362       13362  2013-07-01  Saint Petersburg  Russia      17.234
# 13363       13363  2013-08-01  Saint Petersburg  Russia      17.153
# 13364       13364  2013-09-01  Saint Petersburg  Russia         NaN
#
# [330 rows x 5 columns]

# %%
tem_ind.loc[cities]
# Out:
#                   Unnamed: 0        date country  avg_temp_c
# city
# Moscow                 10725  2000-01-01  Russia      -7.313
# Moscow                 10726  2000-02-01  Russia      -3.551
# Moscow                 10727  2000-03-01  Russia      -1.661
# Moscow                 10728  2000-04-01  Russia      10.096
# Moscow                 10729  2000-05-01  Russia      10.357
# ...                      ...         ...     ...         ...
# Saint Petersburg       13360  2013-05-01  Russia      12.355
# Saint Petersburg       13361  2013-06-01  Russia      17.185
# Saint Petersburg       13362  2013-07-01  Russia      17.234
# Saint Petersburg       13363  2013-08-01  Russia      17.153
# Saint Petersburg       13364  2013-09-01  Russia         NaN
#
# [330 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

avocados = pd.read_pickle('avoplotto.pkl')
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
by_size = avocados.groupby('size')['nb_sold'].sum()
print(by_size)
# Out:
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %%
by_size.plot(kind = 'bar')
plt.show()

# %%
byDate = avocados.groupby('date')['nb_sold'].sum()
byDate.plot(kind = 'line', rot = 45)
plt.show()

# %%
avocados.plot(x='nb_sold', y='avg_price', kind = 'scatter', title = 'Number of avocados sold vs. average price')
 
# Show the plot
plt.show()

# %%
avocados[avocados['type'] == 'conventional']['avg_price'].plot(kind = 'hist',alpha = 0.6)
avocados[avocados['type'] == 'organic']['avg_price'].plot(kind = 'hist',alpha = 0.6)
plt.legend(['conventional','legend'])
plt.show()

# %%
av2 = pd.read_csv('avocados_2016.csv')
av2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        date          type  year  avg_price   size  \
# 0            52          52  2016-12-25  conventional  2016       1.00  small
# 1            53          53  2016-12-18  conventional  2016       0.96  small
# 2            54          54  2016-12-11  conventional  2016       0.98  small
# 3            55          55  2016-12-04  conventional  2016       1.00  small
# 4            56          56  2016-11-27  conventional  2016       1.21  small
#
#        nb_sold
# 0   9255125.20
# 1   9394065.91
# 2   9009996.11
# 3  11043350.90
# 4   7891487.94

# %%
av2.isna().any()
# Out:
# Unnamed: 0.1    False
# Unnamed: 0      False
# date            False
# type            False
# year            False
# avg_price       False
# size            False
# nb_sold         False
# dtype: bool

# %%
av2.isna().sum().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
gdp = pd.read_csv('WorldBank_GDP.csv')
gdp.head(100)
# Out:
#      Country Name Country Code     Indicator Name  Year           GDP
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12
# 11  United States          USA  GDP (current US$)  2012  1.619700e+13
# ...

# %%
yeargap = gdp[(gdp['Year'] < 2018) & (gdp['Year'] > 2010)]
countrygroup = yeargap.groupby('Country Name')['GDP'].sum()
countrygroup.plot(kind='bar')
# Out:
# <Axes: xlabel='Country Name'>

# %%
temperature = pd.read_csv('temperatures.csv')
temperature.head(200)
# Out:
#      Unnamed: 0        date         city        country  avg_temp_c
# 0             0  2000-01-01      Abidjan  Côte D'Ivoire      27.293
# 1             1  2000-02-01      Abidjan  Côte D'Ivoire      27.685
# 2             2  2000-03-01      Abidjan  Côte D'Ivoire      29.061
# 3             3  2000-04-01      Abidjan  Côte D'Ivoire      28.162
# 4             4  2000-05-01      Abidjan  Côte D'Ivoire      27.547
# ..          ...         ...          ...            ...         ...
# 195         195  2002-07-01  Addis Abeba       Ethiopia      17.518
# 196         196  2002-08-01  Addis Abeba       Ethiopia      17.171
# 197         197  2002-09-01  Addis Abeba       Ethiopia      17.405
# 198         198  2002-10-01  Addis Abeba       Ethiopia      17.324
# 199         199  2002-11-01  Addis Abeba       Ethiopia      17.964
#
# [200 rows x 5 columns]

# %%
country_temp = temperature.groupby('country')['avg_temp_c'].mean().reset_index()
country = country_temp.idxmax()
val = country_temp.max()
print(country)
print(val)
# Out:
# country       48
# avg_temp_c    38
# dtype: int64
# country       Zimbabwe
# avg_temp_c    29.98178
# dtype: object

# %%
tem_range = country_temp[(country_temp['avg_temp_c'] > 20) & (country_temp['avg_temp_c'] < 30)]
print(tem_range.count())
# Out:
# country       25
# avg_temp_c    25
# dtype: int64

# %%
print(tem_range.sort_values('avg_temp_c', ascending=True))
# Out:
#                                country  avg_temp_c
# 48                            Zimbabwe   20.721988
# 9                             Colombia   21.649607
# 13                               Egypt   22.044807
# 40                              Taiwan   23.078829
# 4                               Brazil   23.906030
# 20                                Iraq   24.074841
# 1                               Angola   24.387659
# 10  Congo (Democratic Republic Of The)   24.504963
# 32                             Senegal   25.425994
# 27                            Pakistan   25.824654
# 3                           Bangladesh   26.164378
# 41                            Tanzania   26.481774
# 17                               India   26.633255
# 12                  Dominican Republic   26.852800
# 11                       Côte D'Ivoire   26.971024
# 29                         Philippines   27.153518
# 26                             Nigeria   27.176191
# ...

# %%
tem_thai = temperature[temperature['country'] == "Thailand"]
tem_thai.head()
# Out:
#       Unnamed: 0        date     city   country  avg_temp_c
# 1320        1320  2000-01-01  Bangkok  Thailand      25.980
# 1321        1321  2000-02-01  Bangkok  Thailand      26.564
# 1322        1322  2000-03-01  Bangkok  Thailand      28.626
# 1323        1323  2000-04-01  Bangkok  Thailand      28.881
# 1324        1324  2000-05-01  Bangkok  Thailand      28.978

# %%
period = tem_thai[(tem_thai['date'] >= "2005-01-01") & (tem_thai['date'] <= '2010-01-01')]
print(period)
# Out:
#       Unnamed: 0        date     city   country  avg_temp_c
# 1380        1380  2005-01-01  Bangkok  Thailand      25.323
# 1381        1381  2005-02-01  Bangkok  Thailand      28.225
# 1382        1382  2005-03-01  Bangkok  Thailand      28.825
# 1383        1383  2005-04-01  Bangkok  Thailand      30.210
# 1384        1384  2005-05-01  Bangkok  Thailand      30.023
# ...          ...         ...      ...       ...         ...
# 1436        1436  2009-09-01  Bangkok  Thailand      28.308
# 1437        1437  2009-10-01  Bangkok  Thailand      27.564
# 1438        1438  2009-11-01  Bangkok  Thailand      26.533
# 1439        1439  2009-12-01  Bangkok  Thailand      25.973
# 1440        1440  2010-01-01  Bangkok  Thailand      26.615
#
# [61 rows x 5 columns]

# %%
avg = period['avg_temp_c'].mean()
print(avg)
# Out:
# 27.76014754098361
